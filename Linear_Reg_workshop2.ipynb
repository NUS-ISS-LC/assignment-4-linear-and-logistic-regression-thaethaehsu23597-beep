# %% [markdown]
# # Linear Regression Example

# %% [raw]
# In this example, we will build a linear regression with two independent variables.  This linear regression model is also called multiple linear regression.
# 1) Load the dataset 'OmniPower.csv'
# 2) Create a Linear Regression Model with two independent variables (Price and Promotion), one dependent variable (Sale)
# 3) Provide input values and predict the Sale
# 4) What is the R square value?

# %% [markdown]
# importing all the libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


df = pd.read_csv('OmniPower.csv')
df.head()



x_values = df[['Price', 'Promotion']]

sales = df['Sales']
sales = df.Sales

print(sales)

x_train, x_test, y_train, y_test = train_test_split(x_values ,sales, test_size=0.1, random_state = 42)


linReg = LinearRegression()

linReg.fit(x_train, y_train)

df1 = pd.DataFrame ({
    'Price': [100,80],
    'Promotion' :[200,300]
})
linReg.predict( df1[['Price','Promotion']])

from sklearn.metrics import r2_score

y_pred = linReg.predict(x_test) 
print('r2_score: ',r2_score(y_test, y_pred))
# Out:
# 0     4141
# 1     3842
# 2     3056
# 3     3519
# 4     4226
# 5     4630
# 6     3507
# 7     3754
# 8     5000
# 9     5120
# 10    4011
# 11    5015
# 12    1916
# 13     675
# 14    3636
# 15    3224
# 16    2295
# 17    2730
# 18    2618
# 19    4421
# 20    4113
# 21    3746
# 22    3532
# 23    3825
# 24    1096
# 25     761
# 26    2088
# 27     820
# 28    2114
# 29    1882
# 30    2159
# 31    1602
# 32    3354
# 33    2927
# Name: Sales, dtype: int64
# r2_score:  0.41549110656812116
